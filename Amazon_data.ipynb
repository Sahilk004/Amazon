# %% [markdown]
# <a href="https://colab.research.google.com/github/Sahilk004/Amazon/blob/main/Amazon_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp

# %%
#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

# %% [markdown]
# #Data Loading

# %%
df = pd.read_csv('/content/amazon.csv')
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
df.shape
# Out:
# (1465, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %% [markdown]
# #Changing Datatype

# %%
#Changing datatype of discounted and actual price , also changing the symbols
df['discounted_price'] = df['discounted_price'].str.replace('₹','')
df['discounted_price'] = df['discounted_price'].str.replace(',','')
df['discounted_price'] = df['discounted_price'].astype('float64')
df['actual_price'] = df['actual_price'].str.replace('₹','')
df['actual_price'] = df['actual_price'].str.replace(',','')
df['actual_price'] = df['actual_price'].astype('float64')

# %%
#Changing Datatype in Discount Percentage
df['discount_percentage'] = df['discount_percentage'].str.replace('%','')
df['discount_percentage'] = df['discount_percentage'].astype('float64')

# %%
#Finding String in rating
df['rating'].value_counts()
# Out:
# rating
# 4.1    244
# 4.3    230
# 4.2    228
# 4.0    129
# 3.9    123
# 4.4    123
# 3.8     86
# 4.5     75
# 4       52
# 3.7     42
# 3.6     35
# 3.5     26
# 4.6     17
# 3.3     16
# 3.4     10
# 4.7      6
# 3.1      4
# 3.0      3
# 4.8      3
# 5.0      3
# 2.8      2
# 3.2      2
# 2.3      1
# |        1
# 2        1
# 3        1
# 2.6      1
# 2.9      1
# Name: count, dtype: int64

# %%
df.query('rating == "|"')
# Out:
#       product_id                                       product_name  \
# 1279  B08L12N5H1  Eureka Forbes car Vac 100 Watts Powerful Sucti...
#
#                                                category  discounted_price  \
# 1279  Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...            2099.0
#
#       actual_price  discount_percentage rating rating_count  \
# 1279        2499.0                 16.0      |          992
#
#                                           about_product  \
# 1279  No Installation is provided for this product|1...
#
#                                                 user_id  \
# 1279  AGTDSNT2FKVYEPDPXAA673AIS44A,AER2XFSWNN4LAUCJ5...
#
#                                               user_name  \
# 1279  Divya,Dr Nefario,Deekshith,Preeti,Prasanth R,P...
#
#                                               review_id  \
# 1279  R2KKTKM4M9RDVJ,R1O692MZOBTE79,R2WRSEWL56SOS4,R...
#
#                                            review_title  \
# ...

# %%
#By searching product id on amazon we get 3.9 so we fill it instead |
df['rating'] = df['rating'].str.replace('|','3.9').astype('float64')

# %%
df['rating_count'] = df['rating_count'].str.replace(',', '').astype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1465 non-null   float64
#  7   rating_count         1463 non-null   float64
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %% [markdown]
# #Statistics of Data

# %%
df.describe()
# Out:
#        discounted_price   actual_price  discount_percentage       rating  \
# count       1465.000000    1465.000000          1465.000000  1465.000000
# mean        3125.310874    5444.990635            47.691468     4.096451
# std         6944.304394   10874.826864            21.635905     0.291620
# min           39.000000      39.000000             0.000000     2.000000
# 25%          325.000000     800.000000            32.000000     4.000000
# 50%          799.000000    1650.000000            50.000000     4.100000
# 75%         1999.000000    4295.000000            63.000000     4.300000
# max        77990.000000  139900.000000            94.000000     5.000000
#
#         rating_count
# count    1463.000000
# mean    18295.541353
# std     42753.864952
# min         2.000000
# 25%      1186.000000
# 50%      5179.000000
# 75%     17336.500000
# max    426973.000000

# %%
print(df['category'].unique())
# Out:
# ['Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables'
#  'Computers&Accessories|NetworkingDevices|NetworkAdapters|WirelessUSBAdapters'
#  'Electronics|HomeTheater,TV&Video|Accessories|Cables|HDMICables'
#  'Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions'
#  'Electronics|HomeTheater,TV&Video|Accessories|RemoteControls'
#  'Electronics|HomeTheater,TV&Video|Televisions|StandardTelevisions'
#  'Electronics|HomeTheater,TV&Video|Accessories|TVMounts,Stands&Turntables|TVWall&CeilingMounts'
#  'Electronics|HomeTheater,TV&Video|Accessories|Cables|RCACables'
#  'Electronics|HomeAudio|Accessories|SpeakerAccessories|Mounts'
#  'Electronics|HomeTheater,TV&Video|Accessories|Cables|OpticalCables'
#  'Electronics|HomeTheater,TV&Video|Projectors'
#  'Electronics|HomeAudio|Accessories|Adapters'
#  'Electronics|HomeTheater,TV&Video|SatelliteEquipment|SatelliteReceivers'
#  'Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|DVICables'
# ...

# %% [markdown]
# #Dealing with Missing Values

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
#Finding percentage of missing values
null_percent = df.isnull().sum()/df.shape[0]*100
null_percent.sort_values(ascending=False)
# Out:
# rating_count           0.136519
# product_id             0.000000
# category               0.000000
# product_name           0.000000
# discounted_price       0.000000
# actual_price           0.000000
# discount_percentage    0.000000
# rating                 0.000000
# about_product          0.000000
# user_id                0.000000
# user_name              0.000000
# review_id              0.000000
# review_title           0.000000
# review_content         0.000000
# img_link               0.000000
# product_link           0.000000
# dtype: float64

# %%
plt.figure(figsize=(22,10))
sns.heatmap(df.isnull(),cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
df[df['rating_count'].isnull()].head()
# Out:
#      product_id                                       product_name  \
# 282  B0B94JPY2N  Amazon Brand - Solimo 65W Fast Charging Braide...
# 324  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
#
#                                               category  discounted_price  \
# 282  Computers&Accessories|Accessories&Peripherals|...             199.0
# 324  Computers&Accessories|Accessories&Peripherals|...             249.0
#
#      actual_price  discount_percentage  rating  rating_count  \
# 282         999.0                 80.0     3.0           NaN
# 324         999.0                 75.0     5.0           NaN
#
#                                          about_product  \
# 282  USB C to C Cable: This cable has type C connec...
# 324  💎[The Fastest Charge] - This iPhone USB C cabl...
#
#                           user_id    user_name      review_id  \
# 282  AE7CFHY23VAJT2FI4NZKKP6GS2UQ       Pranav   RUB7U91HVZ30
# ...

# %%
print(df['rating_count'].describe()) #If max is much larger than mean or 75% we apply median
# Out:
# count      1463.000000
# mean      18295.541353
# std       42753.864952
# min           2.000000
# 25%        1186.000000
# 50%        5179.000000
# 75%       17336.500000
# max      426973.000000
# Name: rating_count, dtype: float64

# %%
rating_count_median = df['rating_count'].median()
df["rating_count"] = df['rating_count'].fillna(rating_count_median)

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %% [markdown]
# #Finding Duplicate Value

# %%
df.duplicated().any()
# Out:
# np.False_

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
any_duplicates = df.duplicated(subset=['product_id', 'product_name', 'category', 'discounted_price',
       'actual_price', 'discount_percentage', 'rating', 'rating_count',
       'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
       'review_content', 'img_link', 'product_link']).any()

# %%
any_duplicates
# Out:
# np.False_

# %% [markdown]
# #EDA & Visualisation

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                 64.0     4.2       24269.0
# ...

# %%
df["category"].value_counts()
# Out:
# category
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables                                          233
# Electronics|WearableTechnology|SmartWatches                                                                                 76
# Electronics|Mobiles&Accessories|Smartphones&BasicMobiles|Smartphones                                                        68
# Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions                                                               63
# Electronics|Headphones,Earbuds&Accessories|Headphones|In-Ear                                                                52
#                                                                                                                           ...
# Home&Kitchen|Kitchen&HomeAppliances|SmallKitchenAppliances|RotiMakers                                                        1
# ...

# %%
df['main_category'] = df['category'].astype(str).str.split('|').str[0]
## Extracts the first (main) category before the first '|' (e.g., 'Electronics|TVs|SmartTV' → 'Electronics')

# %%
df['main_category'].head()
# Out:
# 0    Computers&Accessories
# 1    Computers&Accessories
# 2    Computers&Accessories
# 3    Computers&Accessories
# 4    Computers&Accessories
# Name: main_category, dtype: object

# %%
## Extracts the last category after splitting by '|' (e.g., 'Electronics|TVs|SmartTV' → 'SmartTV')
df['sub_category'] = df['category'].astype(str).str.split('|').str[-1]
df['sub_category']
# Out:
# 0                      USBCables
# 1                      USBCables
# 2                      USBCables
# 3                      USBCables
# 4                      USBCables
#                   ...
# 1460    WaterPurifierAccessories
# 1461           Rice&PastaCookers
# 1462              HeatConvectors
# 1463                 ExhaustFans
# 1464              SandwichMakers
# Name: sub_category, Length: 1465, dtype: object

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link', 'main_category',
#        'sub_category'],
#       dtype='object')

# %%
df[['rating_count','rating']]
# Out:
#       rating_count  rating
# 0          24269.0     4.2
# 1          43994.0     4.0
# 2           7928.0     3.9
# 3          94363.0     4.2
# 4          16905.0     4.2
# ...            ...     ...
# 1460        1090.0     4.0
# 1461        4118.0     4.1
# 1462         468.0     3.6
# 1463        8031.0     4.0
# 1464        6987.0     4.3
#
# [1465 rows x 2 columns]

# %%
df["rating_weight"] = df["rating"] * df["rating_count"]
#this is rating weight: avg number of people rated
df["rating_weight"]
# Out:
# 0       101929.8
# 1       175976.0
# 2        30919.2
# 3       396324.6
# 4        71001.0
#           ...
# 1460      4360.0
# 1461     16883.8
# 1462      1684.8
# 1463     32124.0
# 1464     30044.1
# Name: rating_weight, Length: 1465, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1465 non-null   float64
#  7   rating_count         1465 non-null   float64
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %% [markdown]
# #Data Visualisation

# %% [markdown]
# Distribution of products by main category

# %%
mainCategoryCount = df['main_category'].value_counts()

# %%
mainCategoryCount
# Out:
# main_category
# Electronics              526
# Computers&Accessories    453
# Home&Kitchen             448
# OfficeProducts            31
# MusicalInstruments         2
# HomeImprovement            2
# Toys&Games                 1
# Car&Motorbike              1
# Health&PersonalCare        1
# Name: count, dtype: int64

# %%
plt.bar(range(len(mainCategoryCount)),mainCategoryCount.values)
plt.ylabel('Number of products')
#plt.xlabel('Products')
plt.xticks(range(len(mainCategoryCount)),'')
plt.show()

# %% [markdown]
# By Observing we get the main three Categories are Electrinics,Computer & Accessories,Home&Kitchen

# %% [markdown]
# Analyze Distribution of customers rating

# %%
plt.hist(df['rating'])
plt.xlabel('Rating')
plt.ylabel('Number of Labels')
plt.title('Customer Rating Distribution')
plt.show()

# %%
bins = [0,1,2,3,4,5]
df['cluster'] = pd.cut(df['rating'],bins =bins,labels =['0-1','1-2','2-3','3-4','4-5'])

# %%
df['cluster'].value_counts().sort_values()
# Out:
# cluster
# 0-1      0
# 1-2      1
# 2-3      9
# 3-4    526
# 4-5    929
# Name: count, dtype: int64

# %% [markdown]
# Majority Falls in the range of 4-5

# %%
#Average rating of each main category
topCategories_byRating = df.groupby(['main_category'])['rating'].mean().sort_values(ascending = False).reset_index()

# %%
topCategories_byRating
# Out:
#            main_category    rating
# 0         OfficeProducts  4.309677
# 1             Toys&Games  4.300000
# 2        HomeImprovement  4.250000
# 3  Computers&Accessories  4.154967
# 4            Electronics  4.081749
# 5           Home&Kitchen  4.040402
# 6    Health&PersonalCare  4.000000
# 7     MusicalInstruments  3.900000
# 8          Car&Motorbike  3.800000

# %%
plt.bar(topCategories_byRating['main_category'],topCategories_byRating['rating'])
plt.xticks(rotation = 90)
plt.xlabel('Main Categories')
plt.ylabel('Average Rating')
plt.title('Top Main Categories by rating')
plt.show()

# %%
#Average rating of each sub category
topRated_subCategories=df.groupby(['sub_category'])['rating'].mean().sort_values(ascending=False).reset_index(0)
topRated_10subCategories= topRated_subCategories.head(10)

# %%
topRated_10subCategories
# Out:
#                       sub_category  rating
# 0                          Tablets     4.6
# 1                   CordManagement     4.5
# 2                            Basic     4.5
# 3                             Film     4.5
# 4                PaintingMaterials     4.5
# 5                           Memory     4.5
# 6                    CoffeePresses     4.5
# 7                 PowerLANAdapters     4.5
# 8  SmallApplianceParts&Accessories     4.5
# 9                 StreamingClients     4.5

# %%
plt.bar(topRated_10subCategories['sub_category'],topRated_10subCategories['rating'])
plt.xticks(rotation = 90)
plt.xlabel('Sub Categories')
plt.ylabel('Average Rating')
plt.title('Top 10 Sub Categories by rating')
plt.show()

# %%
topRated_subCategories.tail()
# Out:
#          sub_category  rating
# 202    InkjetPrinters     3.6
# 203         3DGlasses     3.5
# 204        PCHeadsets     3.5
# 205        DustCovers     3.4
# 206  ElectricGrinders     3.3

# %%
#Discount Percentage in Main Category
avg_discount_percent_MCategroy = df.groupby(['main_category'])['discount_percentage'].mean().sort_values(ascending = False).reset_index()
avg_discount_percent_MCategroy
# Out:
#            main_category  discount_percentage
# 0        HomeImprovement            57.500000
# 1  Computers&Accessories            54.024283
# 2    Health&PersonalCare            53.000000
# 3            Electronics            50.828897
# 4     MusicalInstruments            46.000000
# 5          Car&Motorbike            42.000000
# 6           Home&Kitchen            40.120536
# 7         OfficeProducts            12.354839
# 8             Toys&Games             0.000000

# %%
plt.barh(avg_discount_percent_MCategroy['main_category'],avg_discount_percent_MCategroy['discount_percentage'])
plt.xticks(rotation = 90)
plt.xlabel('Main Categories')
plt.ylabel('Average Discount Percentage')
plt.title('Average Discount Percentage in Main Categories')
plt.show()

# %% [markdown]
# Observation:
#
# Toys&Games has 0 discount. it means it has high demand
#
# Home Improvement has max discount of 57%
#
# Computer assecories, health and personal care, electronics have almost same discount percentage

# %%
# sub category
top20_avg_discount_percentage_SCategory=df.groupby('sub_category')['discount_percentage'].mean().sort_values(ascending=False).head(20)
top20_avg_discount_percentage_SCategory.reset_index()
# Out:
#                  sub_category  discount_percentage
# 0   CableConnectionProtectors            90.000000
# 1                     Earpads            90.000000
# 2                 PhoneCharms            90.000000
# 3                  DustCovers            87.500000
# 4           Shower&WallMounts            82.000000
# 5                    Adapters            80.333333
# 6          InternalHardDrives            80.000000
# 7            USBtoUSBAdapters            78.500000
# 8                      Stands            75.818182
# 9      NotebookComputerStands            75.666667
# 10               VideoCameras            75.000000
# 11                    Caddies            75.000000
# 12        Bedstand&DeskMounts            74.500000
# 13                      Décor            73.200000
# 14      InkjetInkRefills&Kits            73.000000
# 15                     Mounts            73.000000
# 16                      Cases            72.333333
# ...

# %%
plt.barh(top20_avg_discount_percentage_SCategory.index, top20_avg_discount_percentage_SCategory.values)
plt.xlabel('Discounted Percentage')
plt.ylabel('Sub Categories')
plt.title('Discount Percentage by Sub Category')
plt.show()

# %%
# alphabetical order
top20SubCategories=df.groupby('sub_category')['discount_percentage'].mean().head(20)
plt.barh(top20SubCategories.index, top20SubCategories.values)
plt.xlabel('')
# Out:
# Text(0.5, 0, '')

# %%
plt.pie(top20SubCategories.values,labels=top20SubCategories.index,autopct = '%1.1f%%')
plt.show()

# %% [markdown]
#  Part-by-Part Explanation:
# plt.pie(...)
#
# ➤ This function draws a pie chart.
#
# top20SubCategories.values
#
# ➤ These are the sizes (like counts or sums) for each slice of the pie.
#
# ➤ Example: [500, 300, 200, ...]
#
# labels=top20SubCategories.index
#
# ➤ These are the labels (names) for each slice.
#
# ➤ Example: ['Mobiles', 'Laptops', 'Headphones', ...]
#
# autopct='%1.1f%%'
#
# ➤ This adds percent values on each slice of the pie.
#
# ➤ '1.1f%%' means: show 1 decimal place (e.g., 23.5%)
#
#
# plt.show()
# ➤ This displays the chart.

# %%
#Price Analysis
mainCategory_actualPrice = df.groupby('main_category')['actual_price'].mean()
plt.barh(mainCategory_actualPrice.index, mainCategory_actualPrice.values)
plt.xlabel('Average Actual Price')
plt.ylabel('Main Categories')
plt.title('Average Actual Price by Main Categories')
plt.show()

# %%
from enum import auto
plt.pie(mainCategory_actualPrice.values,labels = mainCategory_actualPrice.index,autopct = '%1.1f%%')
plt.show()

# %% [markdown]
# #Analysing Reviews
# Creating a word cloud word cloud showing the most frequent words in customer reviews

# %%
df['review_content'][0]
# Out:
# 'Looks durable Charging is fine tooNo complains,Charging is really fast, good product.,Till now satisfied with the quality.,This is a good product . The charging speed is slower than the original iPhone cable,Good quality, would recommend,https://m.media-amazon.com/images/W/WEBP_402378-T1/images/I/81---F1ZgHL._SY88.jpg,Product had worked well till date and was having no issue.Cable is also sturdy enough...Have asked for replacement and company is doing the same...,Value for money'

# %%
#df['review_content'].values

# %%
#' '.join(...) Joins all the reviews into one big string, with a space between each review.
reviewContent = ' '.join(df['review_content'].dropna().values)
#Combining all review content
#reviewContent

# %%
from wordcloud import WordCloud
review_worldCloud = WordCloud(width=1500, height=800).generate(reviewContent)
plt.figure(figsize=(10,10))
plt.imshow(review_worldCloud)
plt.axis('off')
plt.show()

# %%
#reviews with rating more than 4
rating4_df=df[df['rating']>4]
rating4_df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# 6  B08WRWPM22  boAt Micro USB 55 Tangle-free, Sturdy Micro US...
# 7  B08DDRGWTJ             MI Usb Type-C Cable Smartphone (Black)
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...            399.00
# 3  Computers&Accessories|Accessories&Peripherals|...            329.00
# 4  Computers&Accessories|Accessories&Peripherals|...            154.00
# 6  Computers&Accessories|Accessories&Peripherals|...            176.63
# 7  Computers&Accessories|Accessories&Peripherals|...            229.00
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                 64.0     4.2       24269.0
# ...

# %%
rating4_review=' '.join(rating4_df['review_content'].dropna().values)

# %%
rating4_review_wordCloud = WordCloud(width=1500, height=800).generate(rating4_review)
plt.figure(figsize=(10,10))
plt.imshow(rating4_review_wordCloud)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1499.5), np.float64(799.5), np.float64(-0.5))

# %% [markdown]
# #Correlation Between Numerical feature

# %%
numerical_df = df.select_dtypes(include = 'float64')
numerical_df.head()
# Out:
#    discounted_price  actual_price  discount_percentage  rating  rating_count  \
# 0             399.0        1099.0                 64.0     4.2       24269.0
# 1             199.0         349.0                 43.0     4.0       43994.0
# 2             199.0        1899.0                 90.0     3.9        7928.0
# 3             329.0         699.0                 53.0     4.2       94363.0
# 4             154.0         399.0                 61.0     4.2       16905.0
#
#    rating_weight
# 0       101929.8
# 1       175976.0
# 2        30919.2
# 3       396324.6
# 4        71001.0

# %%
correlation_matrix=numerical_df.corr()
correlation_matrix
# Out:
#                      discounted_price  actual_price  discount_percentage  \
# discounted_price             1.000000      0.961915            -0.242412
# actual_price                 0.961915      1.000000            -0.118098
# discount_percentage         -0.242412     -0.118098             1.000000
# rating                       0.120386      0.121744            -0.154563
# rating_count                -0.027081     -0.035959             0.011097
# rating_weight               -0.026816     -0.035703             0.010495
#
#                        rating  rating_count  rating_weight
# discounted_price     0.120386     -0.027081      -0.026816
# actual_price         0.121744     -0.035959      -0.035703
# discount_percentage -0.154563      0.011097       0.010495
# rating               1.000000      0.101700       0.114706
# rating_count         0.101700      1.000000       0.999061
# rating_weight        0.114706      0.999061       1.000000

# %%
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# #Recommendation System

# %%
df["user_id"][0]
# Out:
# 'AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBBSNLYT3ONILA,AHCTC6ULH4XB6YHDY6PCH2R772LQ,AGYHHIERNXKA6P5T7CZLXKVPT7IQ,AG4OGOFWXJZTQ2HKYIOCOY3KXF2Q,AENGU523SXMOS7JPDTW52PNNVWGQ,AEQJHCVTNINBS4FKTBGQRQTGTE5Q,AFC3FFC5PKFF5PMA52S3VCHOZ5FQ'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1465 non-null   float64
#  7   rating_count         1465 non-null   float64
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
#Converting to float datatype so we can appply operations
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['encoded_user_id'] = le.fit_transform(df['user_id'])
df['encoded_user_id'].value_counts()
# Out:
# encoded_user_id
# 1048    10
# 623      8
# 674      8
# 88       7
# 254      7
#         ..
# 755      1
# 358      1
# 717      1
# 344      1
# 24       1
# Name: count, Length: 1194, dtype: int64

# %%
user_id_freq_table= pd.DataFrame({'UserID': df['encoded_user_id'].value_counts().index, 'Frequency': df['encoded_user_id'].value_counts().values})
user_id_freq_table
# Out:
#       UserID  Frequency
# 0       1048         10
# 1        623          8
# 2        674          8
# 3         88          7
# 4        254          7
# ...      ...        ...
# 1189     755          1
# 1190     358          1
# 1191     717          1
# 1192     344          1
# 1193      24          1
#
# [1194 rows x 2 columns]

# %%
# to see what has been transformed to1048
le.inverse_transform([1048])
# Out:
# array(['AHIKJUDTVJ4T6DV6IUGFYZ5LXMPA,AE55KTFVNXYFD5FPYWP2OUPEYNPQ,AEBWA5I4QFCA3P3OBEPMELBGN4GQ,AHMGAC6QM62UXNEOCZIHLHSXPP2Q,AFHROSCGIXUPV3FYQ7H5QOD46Q7Q,AEAMIR3CMSA32IDEINSJKHRNANTA,AF355FTXYAKFH5NYPRTE7SL3WO3Q,AG5DWPD54QGSLWJ6QUFERLPNAX4Q'],
#       dtype=object)

# %% [markdown]
# TfidfVectorizer is a tool used to convert text data (like reviews or comments) into numbers so that machine learning models can understand and work with them.
#
# What does "TF-IDF" mean?
# It stands for:
#
# TF = Term Frequency (how often a word appears in a document)
#
# IDF = Inverse Document Frequency (how common or rare the word is across all documents)
#
# Together:
#
# Words that appear a lot in one review but not in others are considered important, so they get a higher score.
#
# Words like "the", "is", "and", etc. are common everywhere, so they get a low score or are removed.
#
# stop_words='english' removes commmon english words

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf= TfidfVectorizer(stop_words='english')

# %%
df['about_product'] = df['about_product'].fillna('')
df['about_product']
# Out:
# 0       High Compatibility : Compatible With iPhone 12...
# 1       Compatible with all Type C enabled devices, be...
# 2       【 Fast Charger& Data Sync】-With built-in safet...
# 3       The boAt Deuce USB 300 2 in 1 cable is compati...
# 4       [CHARGE & SYNC FUNCTION]- This cable comes wit...
#                               ...
# 1460    SUPREME QUALITY 90 GRAM 3 LAYER THIK PP SPUN F...
# 1461                         230 Volts, 400 watts, 1 Year
# 1462    International design and styling|Two heat sett...
# 1463    Fan sweep area: 230 MM ; Noise level: (40 - 45...
# 1464    Brand-Borosil, Specification â€“ 23V ~ 5Hz;1 W...
# Name: about_product, Length: 1465, dtype: object

# %%
tfidf_matrix=tfidf.fit_transform(df['about_product'])

# %%
user_product_details=df[df['encoded_user_id']==900] #Checking user with id 900

# %%
user_product_details
# Out:
#      product_id                                       product_name  \
# 716  B08FB2LNSZ  JBL Tune 215BT, 16 Hrs Playtime with Quick Cha...
#
#                                               category  discounted_price  \
# 716  Electronics|Headphones,Earbuds&Accessories|Hea...            1499.0
#
#      actual_price  discount_percentage  rating  rating_count  \
# 716        2999.0                 50.0     3.7       87798.0
#
#                                          about_product  \
# 716  Enjoy balanced sound without artificially enha...
#
#                                                user_id  ...  \
# 716  AGZCXPBXKXIEQTY4AH7KM6OPQW3Q,AF7IPRBRDY6D4F7XV...  ...
#
#                                              review_id  \
# 716  R3NMIVJ17E0X21,RB5W0IR72WUCL,RYFMIDRTCXL9G,RAX...
#
#                                           review_title  \
# 716  Good headphones, the sound is good, not sure a...
#
#                                         review_content  \
# ...

# %% [markdown]
# What is Cosine Similarity?
#
# Cosine similarity is a method used to measure how similar two pieces of text (or vectors) are — based on the angle between them, not their length.

# %%
indices = user_product_details.index.tolist()
indices
# Out:
# [716]

# %%
from sklearn.metrics.pairwise import cosine_similarity
cosine_similarity_user = cosine_similarity(tfidf_matrix[indices],tfidf_matrix)

# %%
cosine_similarity_user
# Out:
# array([[0.03457362, 0.02342515, 0.04488096, ..., 0.        , 0.03494306,
#         0.        ]])

# %%
products=df.iloc[indices]['product_name']

indices= pd.Series(products.index, index=products)
indices
# Out:
# product_name
# JBL Tune 215BT, 16 Hrs Playtime with Quick Charge, in Ear Bluetooth Wireless Earphones with Mic, 12.5mm Premium Earbuds with Pure Bass, BT 5.0, Dual Pairing, Type C & Voice Assistant Support (Black)    716
# dtype: int64

# %%
similarity_scores=list(enumerate(cosine_similarity_user[-1]))
similarity_scores=[(i,score) for (i,score) in similarity_scores if i not in indices]
similarity_scores=sorted(similarity_scores, key=lambda x:x[1],reverse=True) # sort based on similarity score

# %%
#top 5 recommended products
top_5_products=[i[0] for i in similarity_scores[1:6]]
top_5_products
# Out:
# [883, 977, 785, 939, 664]

# %%
#name of top 5 products
recommended_products=df.iloc[top_5_products]['product_name'].tolist()
recommended_products
# Out:
# ['Infinity (JBL Glide 510, 72 Hrs Playtime with Quick Charge, Wireless On Ear Headphone with Mic, Deep Bass, Dual Equalizer, Bluetooth 5.0 with Voice Assistant Support (Black)',
#  'Sennheiser CX 80S in-Ear Wired Headphones with in-line One-Button Smart Remote with Microphone Black',
#  'Noise Buds VS201 V2 in-Ear Truly Wireless Earbuds with Dual Equalizer | with Mic | Total 14-Hour Playtime | Full Touch Control | IPX5 Water Resistance and Bluetooth v5.1 (Olive Green)',
#  'Wecool Moonwalk M1 ENC True Wireless in Ear Earbuds with Mic, Titanium Drivers for Rich Bass Experience, 40+ Hours Play Time, Type C Fast Charging, Low Latency, BT 5.3, IPX5, Deep Bass (Black)',
#  'boAt Rockerz 550 Over Ear Bluetooth Headphones with Upto 20 Hours Playback, 50MM Drivers, Soft Padded Ear Cushions and Physical Noise Isolation, Without Mic (Black)']

# %%
#lets convert all in DF
top5scores=[similarity_scores[i][1] for i in range(5)]
top5scores
# Out:
# [np.float64(0.9999999999999996),
#  np.float64(0.3299631371523861),
#  np.float64(0.31592300978836335),
#  np.float64(0.20870111277385178),
#  np.float64(0.2053676966074428)]

# %%
result_df=pd.DataFrame({'Encoded_ID':900, 'Recommended Products': recommended_products, 'Recommended Score': top5scores})
result_df
# Out:
#    Encoded_ID                               Recommended Products  \
# 0         900  Infinity (JBL Glide 510, 72 Hrs Playtime with ...
# 1         900  Sennheiser CX 80S in-Ear Wired Headphones with...
# 2         900  Noise Buds VS201 V2 in-Ear Truly Wireless Earb...
# 3         900  Wecool Moonwalk M1 ENC True Wireless in Ear Ea...
# 4         900  boAt Rockerz 550 Over Ear Bluetooth Headphones...
#
#    Recommended Score
# 0           1.000000
# 1           0.329963
# 2           0.315923
# 3           0.208701
# 4           0.205368

# %%
def recommendation_system(df, encoded_user_id):
    tfidf = TfidfVectorizer(stop_words='english')
    df['about_product'] = df['about_product'].fillna('')
    tfidf_matrix = tfidf.fit_transform(df['about_product'])
    user_product_details = df[df['encoded_user_id'] == encoded_user_id]
    indices = user_product_details.index.tolist()
    if indices:
        cosine_similairty_user = cosine_similarity(tfidf_matrix[indices], tfidf_matrix)

        products = df.iloc[indices]['product_name']

        indices = pd.Series(products.index, index=products)
        similiarity_scores = list(enumerate(cosine_similairty_user[-1]))
        similiarity_scores=[(i, score) for (i,score) in similiarity_scores if i not in indices]
        similiarity_scores= sorted(similiarity_scores, key=lambda x:x[1], reverse=True) #sort based on similiarty scores
        top_5_products = [i[0] for i in similiarity_scores[1:6]]
        #name of top 5 products
        recommended_products = df.iloc[top_5_products]['product_name'].tolist()

        top5scores = [similiarity_scores[i][1] for i in range(5)]
        result_df = pd.DataFrame({'Encoded_ID': encoded_user_id, 'Recommended Products': recommended_products, 'Recommended Score': top5scores})
        return result_df
        return "Id Incorrect"

# %%
recommendation_system(df, 1048)
# Out:
#    Encoded_ID                               Recommended Products  \
# 0        1048        Flix Micro Usb Cable For Smartphone (Black)
# 1        1048        Flix Micro Usb Cable For Smartphone (Black)
# 2        1048  FLiX (Beetel USB to Micro USB PVC Data Sync & ...
# 3        1048  pTron Solero M241 2.4A Micro USB Data & Chargi...
# 4        1048  Flix (Beetel) Usb To Type C Pvc Data Sync And ...
#
#    Recommended Score
# 0           1.000000
# 1           1.000000
# 2           1.000000
# 3           0.911706
# 4           0.677355
